# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravanireddy1998/Pandas_tasks/blob/main/task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a74deab2-9598-4ed9-9202-f120195e6ca5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a74deab2-9598-4ed9-9202-f120195e6ca5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving college_1.csv to college_1.csv

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a700718e-ba3a-4e31-828b-84f7c98b2a5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a700718e-ba3a-4e31-828b-84f7c98b2a5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving college_2.csv to college_2.csv

# %%
df1=pd.read_csv("college_1.csv")

# %%
df2=pd.read_csv("college_2.csv")

# %%
print(df1)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
df2.drop(["python_en","computational_thinking"], axis=1)
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0            ASHOK KUMAR K     100     31              19400           19400
# 1                  Chandru       0      0              14150           14490
# 2        Ganesh Ramkumar R      -1     24               8790           10790
# 3          Bodipudi Harini      -1     35              10040           10040
# 4                VIINU V P      -1     24               9150            9150
# 5               Poojitha Y       0     35               7210            8970
# 6   Gowtham Chandrasekaran      -1      0               7250            8950
# 7                Gowtham R      -1      4               8650            8650
# 8                 shifak N      58      0               5180            8320
# 9                  Balaji       -1     20               6170            8160
# 10                Rushitha      -1     62               7470            8090
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df3=pd.concat([df1,df2],ignore_index=True)

# %%
df3.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
df3.tail(10)
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 109       SHAIK DANISH    -1.0    0.0               4050            4820
# 110          sridhar.s    -1.0    0.0               3860            4440
# 111  Vimalesh Fernando    -1.0    0.0               4170            4170
# 112      M.Karthikeyan    -1.0    4.0               4020            4020
# 113          Abishak s    -1.0   35.0               3220            3220
# 114      praveen raj j    24.0    0.0               2380            2380
# 115         AMARNATH D    -1.0   12.0               1890            1890
# 116               bala    32.0    0.0               1720            1720
# 117               XY Z    -1.0   -1.0                  0               0
# 118          Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 109           Computer Science and Engineering     770       43.0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
  df4=df3.loc[df3["CodeKata Score"]>15000]

# %%
df4.head(5)
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %%
df4.to_csv("Exceeded_expectations.csv",index=False)

# %%
df4.to_csv("C:\\Users\\srvnin\\task4\\Exceeded_expectations.csv")

# %%
df5=df3.loc[(df3["CodeKata Score"]>10000)& (df3["CodeKata Score"]<15000)]

# %%
df5.head(20)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        NaN
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      NaN
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %%
df5.to_csv("Reached_expectations.csv",index=False)

# %%
df5.to_csv("C:\\Users\\srvnin\\task4\\Reached_expectations.csv")

# %%
df6=df3.loc[(df3["CodeKata Score"]>7000)& (df3["CodeKata Score"]<10000)]

# %%
df6.to_csv("Needs_Improvement.csv",index=False)

# %%
df6.to_csv("C:\\Users\\srvnin\\task4\\Needs_Improvement.csv")

# %%
df7=df3.loc[df3["CodeKata Score"]>7000]

# %%
df7.to_csv("Unsatisfactory.csv",index=False)

# %%
df7.to_csv("C:\\Users\\srvnin\\task4\\Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df3.iloc[:,3:5].apply(np.mean)
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
df3.shape
# Out:
# (119, 9)

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df3.iloc[:,2:3].apply(np.mean)
# Out:
# mysql    23.5
# dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df3.nlargest(3,columns=["Rising"])
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking
# 92                      0.0
# 86                      6.0
# 102                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df3.nlargest(3,columns=["Previous Geekions"])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt
Department_data = df3["Department"]
Codekata_data = df3["CodeKata Score"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"] 
plt.pie(Codekata_data, labels=Department_data, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb4d3ef8250>,
# ...
#  [Text(1.0860141201866824, 0.17485231126623996, 'Computer Science and Engineering'),
#   Text(0.9852089900569814, 0.48924763250413694, 'Computer Science and Engineering'),
#   Text(0.8191070114794136, 0.734209577535777, 'Computer Science and Engineering'),
#   Text(0.659241947843894, 0.8805680292873393, 'Computer Science and Engineering'),
#   Text(0.5417865176208765, 0.9573230224559753, 'Computer Science and Engineering'),
#   Text(0.43145743321329394, 1.0118520066318968, 'Computer Science and Engineering'),
#   Text(0.32327172245809677, 1.0514254103163836, 'Electronics and Communication Engineering'),
#   Text(0.2198337936058385, 1.0778094002136305, 'Computer Science and Engineering'),
#   Text(0.12871459702241747, 1.0924433864111023, 'Electronics and Communication Engineering'),
#   Text(0.047575564493103725, 1.0989706846240999, 'Computer Science and Engineering'),
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)
